# %%
import numpy as np
import pandas as pd

# %%
median_gain_5dd_performances = pd.read_csv('data/stock/03_model/performance/medianGain/5dd.csv').dropna()
max_loss_5dd_performances = pd.read_csv('data/stock/03_model/performance/maxLoss/5dd.csv').dropna()

# %%
median_gain_5dd_performances.describe()
# Out:
#        Train - Accuracy  Train - Precision High Gain  \
# count        895.000000                   895.000000
# mean           0.867468                     0.863850
# std            0.050482                     0.051595
# min            0.690598                     0.624665
# 25%            0.831215                     0.829457
# 50%            0.850791                     0.848552
# 75%            0.895190                     0.887005
# max            1.000000                     1.000000
#
#        Train - Precision Low Gain  Train - Recall High Gain  \
# count                  895.000000                895.000000
# mean                     0.863850                  0.383600
# std                      0.051595                  0.269965
# min                      0.624665                  0.000000
# 25%                      0.829457                  0.191507
# 50%                      0.848552                  0.287293
# 75%                      0.887005                  0.529146
# ...

# %%
median_gain_5dd_performances[median_gain_5dd_performances['Kode'].isin(['BBCA', 'BBRI'])]
# Out:
#      Kode  Train - Accuracy  Train - Precision High Gain  \
# 94   BBCA          0.811580                     0.809191
# 100  BBRI          0.815505                     0.815895
#
#      Train - Precision Low Gain  Train - Recall High Gain  \
# 94                     0.809191                  0.081731
# 100                    0.815895                  0.098522
#
#      Train - Recall Low Gain  Train - Gini  Test - Accuracy  \
# 94                  0.998767      0.412916         0.842105
# 100                 0.993873      0.425046         0.815789
#
#      Test - Precision High Gain  Test - Precision Low Gain  \
# 94                     0.846847                   0.846847
# 100                    0.816514                   0.816514
#
#      Test - Recall High Gain  Test - Recall Low Gain  Test - Gini  Threshold
# 94                  0.105263                0.989474     0.170637   1.256709
# 100                 0.166667                0.988889     0.086574   1.635194

# %%
median_gain_5dd_forecasts = pd.read_csv('data/stock/04_forecast/medianGain/5dd.csv').dropna()
max_loss_5dd_forecasts = pd.read_csv('data/stock/04_forecast/maxLoss/5dd.csv').dropna()

# %%
median_gain_5dd_forecasts.describe()
# Out:
#        Forecast High Gain 5dd
# count              914.000000
# mean                 0.218197
# std                  0.178777
# min                  0.000128
# 25%                  0.113808
# 50%                  0.183131
# 75%                  0.249025
# max                  0.992869

# %% [markdown]
# # 5 dd Analysis

# %%
merged_win_data =  pd.merge(
                            median_gain_5dd_forecasts[median_gain_5dd_forecasts['Forecast High Gain 5dd'] >= 0.5].sort_values('Forecast High Gain 5dd', ascending=False),
                            median_gain_5dd_performances[median_gain_5dd_performances['Test - Gini'] >= 0.4],
                            on='Kode',
                            how='inner'
                        )


filtered_win_data = merged_win_data[merged_win_data['Threshold'] > 0] \
                        .reset_index(drop=True)

selected_win_emiten = filtered_win_data['Kode'].values

# %%
filtered_win_data
# Out:
#    Kode        Date  Forecast High Gain 5dd  Train - Accuracy  \
# 0  AEGS  2025-11-10                0.881581          0.916279
# 1  INET  2025-11-10                0.845459          0.993478
# 2  LABA  2025-11-10                0.741559          0.980682
# 3  PBRX  2025-11-10                0.672245          0.934783
# 4  ESTA  2025-11-10                0.630901          0.884200
# 5  IOTF  2025-11-10                0.590767          0.973430
# 6  CGAS  2025-11-10                0.583624          0.985994
# 7  GMTD  2025-11-10                0.566900          0.847162
# 8  CBDK  2025-11-10                0.534178          0.985816
#
#    Train - Precision High Gain  Train - Precision Low Gain  \
# 0                     0.911227                    0.911227
# 1                     0.997312                    0.997312
# 2                     0.976744                    0.976744
# 3                     0.928218                    0.928218
# ...

# %%
merged_win_data =  pd.merge(
                            median_gain_5dd_forecasts[median_gain_5dd_forecasts['Forecast High Gain 5dd'] >= 0.5].sort_values('Forecast High Gain 5dd', ascending=False),
                            median_gain_5dd_performances[median_gain_5dd_performances['Test - Gini'] >= 0.5],
                            on='Kode',
                            how='inner'
                        )


filtered_win_data = merged_win_data[merged_win_data['Threshold'] > 0] \
                        .reset_index(drop=True)

selected_win_emiten = filtered_win_data['Kode'].values

# %%
filtered_win_data.head(20)
# Out:
#    Kode        Date  Forecast High Gain 5dd  Train - Accuracy  \
# 0  ESTA  2025-11-10                0.630901          0.884200
# 1  IOTF  2025-11-10                0.590767          0.973430
# 2  CGAS  2025-11-10                0.583624          0.985994
# 3  GMTD  2025-11-10                0.566900          0.847162
# 4  CBDK  2025-11-10                0.534178          0.985816
#
#    Train - Precision High Gain  Train - Precision Low Gain  \
# 0                     0.885083                    0.885083
# 1                     0.972727                    0.972727
# 2                     0.989510                    0.989510
# 3                     0.850242                    0.850242
# 4                     0.982301                    0.982301
#
#    Train - Recall High Gain  Train - Recall Low Gain  Train - Gini  \
# 0                  0.490196                 0.982822      0.823451
# 1                  0.901099                 0.993808      0.996734
# ...

# %%
merged_lose_data =  pd.merge(
                                max_loss_5dd_forecasts[max_loss_5dd_forecasts['Kode'].isin(selected_win_emiten)],
                                max_loss_5dd_performances,
                                on='Kode',
                                how='inner'
                            ) \
                        .sort_values('Threshold', ascending=False) \
                        .reset_index(drop=True)

# %%
merged_lose_data
# Out:
#    Kode        Date  Forecast Low Risk 5dd  Train - Accuracy  \
# 0  GMTD  2025-11-10               0.667054          0.897380
# 1  ESTA  2025-11-10               0.440761          0.646712
# 2  CBDK  2025-11-10               0.559810          0.858156
# 3  CGAS  2025-11-10               0.740572          0.957983
# 4  IOTF  2025-11-10               0.627023          0.881643
#
#    Train - Precision Low Risk  Train - Precision High Risk  \
# 0                    0.871186                     0.871186
# 1                    0.630865                     0.630865
# 2                    0.838710                     0.838710
# 3                    0.950226                     0.950226
# 4                    0.871698                     0.871698
#
#    Train - Recall Low Risk  Train - Recall High Risk  Train - Gini  \
# 0                 0.802083                  0.966165      0.922834
# 1                 0.132353                  0.990180      0.420598
# ...
