# %%
import numpy as np
import pandas as pd

# %%
def dd_analysis(days):
    median_gain_dd_performances = pd.read_csv(f'data/stock/03_model/performance/medianGain/{days}dd.csv').dropna()    
    median_gain_dd_forecasts = pd.read_csv(f'data/stock/04_forecast/medianGain/{days}dd.csv').dropna()

    merged_win_data =  pd.merge(
                                median_gain_dd_forecasts[median_gain_dd_forecasts[f'Forecast High Gain {days}dd'] >= 0.5].sort_values(f'Forecast High Gain {days}dd', ascending=False),
                                median_gain_dd_performances[median_gain_dd_performances['Test - Gini'] >= 0.3],
                                on='Kode',
                                how='inner'
                            )
    
    
    filtered_win_data = merged_win_data[merged_win_data['Threshold'] > 0] \
                            .reset_index(drop=True)
    
    selected_win_emiten = filtered_win_data['Kode'].values

    # max_loss_dd_performances = pd.read_csv(f'data/stock/03_model/performance/maxLoss/{days}dd.csv').dropna()
    # max_loss_dd_forecasts = pd.read_csv(f'data/stock/04_forecast/maxLoss/{days}dd.csv').dropna()
    # merged_lose_data =  pd.merge(
    #                                 max_loss_dd_forecasts[max_loss_dd_forecasts['Kode'].isin(selected_win_emiten)],
    #                                 max_loss_dd_performances,
    #                                 on='Kode',
    #                                 how='inner'
    #                             ) \
    #                         .sort_values('Threshold', ascending=False) \
    #                         .reset_index(drop=True)

    
    merged_lose_data = None

    performance_summary = median_gain_dd_performances.describe()
    
    return filtered_win_data, merged_lose_data, performance_summary

# %% [markdown]
# # 5dd Analysis

# %%
filtered_win_data, merged_lose_data, performance_summary = dd_analysis(5)

# %%
filtered_win_data
# Out:
#    Kode        Date  Forecast High Gain 5dd  Train - Accuracy  \
# 0  FASW  2025-02-26                0.566778          0.921927
#
#    Train - Precision High Gain  Train - Precision Low Gain  \
# 0                     0.919105                    0.919105
#
#    Train - Recall High Gain  Train - Recall Low Gain  Train - Gini  \
# 0                  0.308824                      1.0      0.933796
#
#    Test - Accuracy  Test - Precision High Gain  Test - Precision Low Gain  \
# 0         0.938776                     0.93617                    0.93617
#
#    Test - Recall High Gain  Test - Recall Low Gain  Test - Gini  Threshold
# 0                      0.4                     1.0          0.7   1.416149

# %%
pd.read_csv('data/stock/model_v2/performance/medianGain/5dd.csv').describe()
# Out:
#        Train - Accuracy  Train - Precision High Gain  \
# count        911.000000                   924.000000
# mean           0.896631                     0.885197
# std            0.099662                     0.145658
# min            0.139605                     0.000000
# 25%            0.865068                     0.863361
# 50%            0.919400                     0.920978
# 75%            0.957045                     0.958775
# max            1.000000                     1.000000
#
#        Train - Precision Low Gain  Train - Recall High Gain  \
# count                  924.000000                924.000000
# mean                     0.885197                  0.029528
# std                      0.145658                  0.055003
# min                      0.000000                  0.000000
# 25%                      0.863361                  0.000000
# 50%                      0.920978                  0.000000
# 75%                      0.958775                  0.033475
# ...

# %%
performance_summary
# Out:
#        Train - Accuracy  Train - Precision High Gain  \
# count        857.000000                   857.000000
# mean           0.934615                     0.934025
# std            0.048508                     0.050012
# min            0.675649                     0.660317
# 25%            0.908144                     0.906771
# 50%            0.943182                     0.943249
# 75%            0.970936                     0.971014
# max            1.000000                     1.000000
#
#        Train - Precision Low Gain  Train - Recall High Gain  \
# count                  857.000000                857.000000
# mean                     0.934025                  0.300850
# std                      0.050012                  0.280429
# min                      0.660317                  0.000000
# 25%                      0.906771                  0.071429
# 50%                      0.943249                  0.226744
# 75%                      0.971014                  0.444444
# ...

# %% [markdown]
# # 10dd Analysis

# %%
filtered_win_data, merged_lose_data, performance_summary = dd_analysis(10)

# %%
filtered_win_data
# Out:
# Empty DataFrame
# Columns: [Kode, Date, Forecast High Gain 10dd, Train - Accuracy, Train - Precision High Gain, Train - Precision Low Gain, Train - Recall High Gain, Train - Recall Low Gain, Train - Gini, Test - Accuracy, Test - Precision High Gain, Test - Precision Low Gain, Test - Recall High Gain, Test - Recall Low Gain, Test - Gini, Threshold]
# Index: []

# %%
performance_summary
# Out:
#        Train - Accuracy  Train - Precision High Gain  \
# count        800.000000                   800.000000
# mean           0.934628                     0.934380
# std            0.052965                     0.053667
# min            0.710808                     0.670043
# 25%            0.908509                     0.907965
# 50%            0.946869                     0.946135
# 75%            0.974062                     0.974003
# max            1.000000                     1.000000
#
#        Train - Precision Low Gain  Train - Recall High Gain  \
# count                  800.000000                800.000000
# mean                     0.934380                  0.303348
# std                      0.053667                  0.303627
# min                      0.670043                  0.000000
# 25%                      0.907965                  0.047078
# 50%                      0.946135                  0.195387
# 75%                      0.974003                  0.488249
# ...

# %% [markdown]
# # 15dd Analysis

# %%
filtered_win_data, merged_lose_data, performance_summary = dd_analysis(15)

# %%
filtered_win_data
# Out:
#    Kode        Date  Forecast High Gain 15dd  Train - Accuracy  \
# 0  NAIK  2025-11-26                 0.641983          0.983240
# 1  DGWG  2025-11-26                 0.557704          0.972222
# 2  PTBA  2025-11-26                 0.501198          0.812798
#
#    Train - Precision High Gain  Train - Precision Low Gain  \
# 0                     0.986111                    0.986111
# 1                     0.971223                    0.971223
# 2                     0.812008                    0.812008
#
#    Train - Recall High Gain  Train - Recall Low Gain  Train - Gini  \
# 0                  0.944444                 0.993007      0.997280
# 1                  0.555556                 1.000000      0.980247
# 2                  0.119816                 0.993976      0.628960
#
#    Test - Accuracy  Test - Precision High Gain  Test - Precision Low Gain  \
# 0         0.800000                    0.800000                   0.800000
# ...

# %%
performance_summary
# Out:
#        Train - Accuracy  Train - Precision High Gain  \
# count        769.000000                   769.000000
# mean           0.935949                     0.935389
# std            0.057788                     0.058745
# min            0.590909                     0.571429
# 25%            0.910220                     0.909276
# 50%            0.950334                     0.949728
# 75%            0.978723                     0.978571
# max            1.000000                     1.000000
#
#        Train - Precision Low Gain  Train - Recall High Gain  \
# count                  769.000000                769.000000
# mean                     0.935389                  0.313456
# std                      0.058745                  0.321777
# min                      0.571429                  0.000000
# 25%                      0.909276                  0.046875
# 50%                      0.949728                  0.184211
# 75%                      0.978571                  0.532663
# ...
